# %% [markdown]
# Use the most basic and common components of Langchain: prompt templates,models and output parsers.
# <br> Build a simple application with Langchain
# <br> Trace application with LangSmith
# <br> Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

#Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x0000023501003E80> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000235010005B0> root_client=<openai.OpenAI object at 0x00000235010004F0> root_async_client=<openai.AsyncOpenAI object at 0x0000023501000220> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
#input and get response form LLM
result=llm.invoke("What is generative AI?")
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019c0fde-be68-7be2-8740-2bf099be1e28,id=019c0fde-be68-7be2-8740-2bf099be1e28

# %%
print(result)
# Out:
# content='Generative AI refers to a subset of artificial intelligence techniques designed to create new content, including text, images, audio, and more. It uses machine learning models, particularly deep learning frameworks, to generate data that mimics existing datasets in various domains. Some of the key approaches and technologies within generative AI include:\n\n1. **Generative Adversarial Networks (GANs):** These consist of two neural networks, a generator and a discriminator, that are trained together. The generator creates new data instances, while the discriminator evaluates them against real data. The goal of the generator is to produce data that is indistinguishable from real data, thus "fooling" the discriminator.\n\n2. **Variational Autoencoders (VAEs):** VAEs are another class of neural networks used for generating data. They work by compressing data into a lower-dimensional latent space and then decoding it back into the original space, allowing for the generation of new variations of the data.\n\n3. **Transformer-based Models:** Models like GPT (Generative Pre-trained Transformer) and its successors have revolutionized the generation of text. They rely on large amounts of data and computational power to create human-like text based on a given input or prompt.\n\n4. **Diffusion Models:** These are increasingly being used for generating high-quality images and have shown promising results in producing realistic content by progressively modifying noise levels to refine the output.\n\nGenerative AI has numerous applications across industries, including entertainment, art, healthcare, and more. It is used for creating artwork, generating synthetic data for research, enhancing video games, producing music, and even in therapeutic settings for creating personalized content or simulations.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 334, 'prompt_tokens': 13, 'total_tokens': 347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_fa7f5b168b', 'id': 'chatcmpl-D3mEoZCG1unLVExMCft6mNWpA0RE9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c0fde-be68-7be2-8740-2bf099be1e28-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 334, 'total_tokens': 347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You ae an expert AI Engineer. Provide me answers based on the questions."),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You ae an expert AI Engineer. Provide me answers based on the questions.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019c0fde-be68-7be2-8740-2bf099be1e28,id=019c0fde-be68-7be2-8740-2bf099be1e28

# %%
chain=prompt|llm
response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019c0fe7-6a7d-7e02-a275-f15baa16ea11,id=019c0fe7-6a7d-7e02-a275-f15baa16ea11; trace=019c0fe7-6a7d-7e02-a275-f15baa16ea11,id=019c0fe7-6a8d-7652-b748-6a88555c5fca; trace=019c0fe7-6a7d-7e02-a275-f15baa16ea11,id=019c0fe7-6a8d-7652-b748-6a88555c5fca; trace=019c0fe7-6a7d-7e02-a275-f15baa16ea11,id=019c0fe7-6aa4-7411-ab8b-6f357c4b6645
# content='Langsmith is a set of tools and services developed by LangChain designed to enhance the development and deployment of applications that rely on language models, such as generative AI and natural language processing applications. It provides features that streamline testing, tracing, debugging, and monitoring, which are crucial for developing reliable and efficient language model-powered applications.\n\nKey features of Langsmith include:\n\n1. **Testing and Evaluation**: Langsmith allows developers to test various aspects of language model interactions, such as prompt construction and output validation, to ensure that applications perform as expected.\n\n2. **Tracing**: The toolset includes capabilities for tracing the execution path of requests through various components of a language model application, helping to identify where issues may arise.\n\n3. **Debugging**: Langsmith provides debugging tools to help developers identify and fix problems in their code, making it easier to fine-tune and optimize applications.\n\n4. **Monitoring**: Langsmith also offers monitoring capabilities to track the performance and usage of language model applications in real-time, ensuring stability and reliability.\n\nThis comprehensive framework is particularly useful for developers working with the LangChain library and aims to facilitate creating scalable and effective language model applications.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 236, 'prompt_tokens': 34, 'total_tokens': 270, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_fa7f5b168b', 'id': 'chatcmpl-D3mO1LAKFs2KYo8ZYO8BxJFntw7co', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c0fe7-6aa4-7411-ab8b-6f357c4b6645-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 34, 'output_tokens': 236, 'total_tokens': 270, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
#stroutput Parser
from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response =chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019c0feb-1c70-7210-a69e-3fd45076f97a,id=019c0feb-1c70-7210-a69e-3fd45076f97a; trace=019c0feb-1c70-7210-a69e-3fd45076f97a,id=019c0feb-1c7c-7340-954d-a4cffba00d68; trace=019c0feb-1c70-7210-a69e-3fd45076f97a,id=019c0feb-1c7c-7340-954d-a4cffba00d68; trace=019c0feb-1c70-7210-a69e-3fd45076f97a,id=019c0feb-1c83-7d52-8110-ce7c2111f1d0
# Langsmith is a tool designed to enhance the development and fine-tuning of applications built using large language models (LLMs). It serves as a platform to improve and manage LLM applications by providing features for testing, evaluating, and monitoring these models. Langsmith allows developers to identify areas where their models may not be performing as expected and provides insights into how to optimize them for better outcomes. By offering tools for structured evaluation, Langsmith helps in refining the application, ensuring it meets desired performance and reliability standards. Features may include logging, analytics, versioning, and error analysis, all aimed at making the iterative process of building with LLMs more efficient and effective.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019c0feb-1c70-7210-a69e-3fd45076f97a,id=019c0feb-1c83-7d52-8110-ce7c2111f1d0; trace=019c0feb-1c70-7210-a69e-3fd45076f97a,id=019c0feb-308e-7052-b544-da608f3caa1b; trace=019c0feb-1c70-7210-a69e-3fd45076f97a,id=019c0feb-308e-7052-b544-da608f3caa1b; trace=019c0feb-1c70-7210-a69e-3fd45076f97a,id=019c0feb-1c70-7210-a69e-3fd45076f97a
